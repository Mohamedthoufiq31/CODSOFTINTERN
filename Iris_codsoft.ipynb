# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris= pd.read_csv('/content/IRIS.csv')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
iris.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
iris = iris.drop(columns = ['species'])
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
iris.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
iris.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
iris = iris.drop(columns = ['sepal_width'])
iris.head()
# Out:
#    sepal_length  petal_length  petal_width
# 0           5.1           1.4          0.2
# 1           4.9           1.4          0.2
# 2           4.7           1.3          0.2
# 3           4.6           1.5          0.2
# 4           5.0           1.4          0.2

# %%
plt.figure(figsize=(10, 6))
sns.histplot(iris['sepal_length'], bins=30, kde=True)
plt.show()

# %%
iris.isnull().sum()
# Out:
# sepal_length    0
# petal_length    0
# petal_width     0
# dtype: int64

# %%
iris.mean()
# Out:
# sepal_length    5.843333
# petal_length    3.758667
# petal_width     1.198667
# dtype: float64

# %%
iris.median()
# Out:
# sepal_length    5.80
# petal_length    4.35
# petal_width     1.30
# dtype: float64

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='petal_width', y='petal_length', data=iris)
plt.title('Size of petal And septal')
plt.show()

# %%
plt.figure(figsize=(12, 8))
sns.boxplot(x='sepal_length', y='petal_width', data=iris)
plt.title('Size of iris Flower Length and width')
plt.show()

# %%
sns.pairplot(iris[['sepal_length', 'petal_length',  'petal_width']])
plt.show()

# %%
iris.max()
# Out:
# sepal_length    7.9
# petal_length    6.9
# petal_width     2.5
# dtype: float64

# %%
iris.min()
# Out:
# sepal_length    4.3
# petal_length    1.0
# petal_width     0.1
# dtype: float64

# %%
sns.violinplot(x=iris["petal_width"])
# Out:
# <Axes: xlabel='petal_width'>

# %%
iris.corr()
# Out:
#               sepal_length  petal_length  petal_width
# sepal_length      1.000000      0.871754     0.817954
# petal_length      0.871754      1.000000     0.962757
# petal_width       0.817954      0.962757     1.000000

# %%
correlation_matrix = iris.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.show()

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
iris['sepal_length'] = le.fit_transform(iris['sepal_length'])
iris.head()
# Out:
#    sepal_length  petal_length  petal_width
# 0             8           1.4          0.2
# 1             6           1.4          0.2
# 2             4           1.3          0.2
# 3             3           1.5          0.2
# 4             7           1.4          0.2

# %%
from sklearn.model_selection import train_test_split
X = iris.drop(columns=['sepal_length'])
Y = iris['sepal_length']
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.30)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print("Accuracy: ",model.score(x_test, y_test) * 100)
# Out:
# Accuracy:  11.11111111111111
